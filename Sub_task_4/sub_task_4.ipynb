# %% [markdown]
# **Step 1 - Train the engine.**
#
# Create a TF-IDF matrix of unigrams, bigrams, and trigrams for each product. The 'stop_words' param tells the TF-IDF module to ignore common english words like 'the', etc.
#
# Then we compute similarity between all articles using SciKit Leanr's linear_kernel (which in this case is equivalent to cosine similarity).
#
# Iterate through each article's similar articles and store the 100 most-similar. You could show more than 100, your choice.
#
# Similarities and their scores are stored in a dictionary as a list of Tuples, indexed to their post id

# %%
# what to install for mysql to work
# ! pip install mysql-connector-python

# %%
import mysql.connector
from sqlalchemy import create_engine

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
#loading the dataset
mydb = mysql.connector.connect(host="remotemysql.com",
                              user="8SawWhnha4",
                              passwd="zFvOBIqbIz",
                              database="8SawWhnha4")

engine = create_engine('mysql+mysqlconnector://8SawWhnha4:zFvOBIqbIz@remotemysql.com/8SawWhnha4')

# %%
#fetching the tables in the dataset
dbcursor = mydb.cursor()
dbcursor.execute('show tables')
for table in dbcursor:
    print(table)
# Out:
# ('comments',)
# ('contact_settings',)
# ('ext_feed_banks',)
# ('ext_rsses',)
# ('extfeeds',)
# ('following',)
# ('interests',)
# ('maillists',)
# ('migrations',)
# ('notifications',)
# ('password_resets',)
# ('posts',)
# ('thoughts',)
# ('user_settings',)
# ('users',)
# ('users_email_login_tokens',)

# %%
#checking out the post table
POSTS = pd.read_sql_query('select * from posts', engine)
POSTS.drop(['user_id', 'tags', 'slug', 'created_at', 'updated_at', 'image',
            'status_id', 'action', 'post_id'], axis=1, inplace=True)
POSTS.head()
# Out:
#    id                              title  \
# 0   1  What i have learnt so far on HTML
# 1   2                   HTML BEGINS HERE
# 2   4            My Laziness In The Open
# 3   6                          MY TASK 2
# 4   7                             Task 2
#
#                                              content
# 0  I learnt how to use the table tag as i have us...
# 1   I am on this journey with start.ng, and here ...
# 2  I have not been attending classes on the HNG c...
# 3  My journey on **StartNG** pre-internship progr...
# 4   A Summary on The “idongesit.html” CV, Its Str...

# %%
POSTS.rename(columns={"id":"post_id"}, inplace=True)

# %%
POSTS.head(50)
# Out:
#     post_id                                              title  \
# 0         1                  What i have learnt so far on HTML
# 1         2                                   HTML BEGINS HERE
# 2         4                            My Laziness In The Open
# 3         6                                          MY TASK 2
# 4         7                                             Task 2
# 5         8                                 My Journey on HTML
# 6         9                            StartNG HTML Exposition
# 7        11                                          MY TASK 2
# 8        12                                  StartNG HTML task
# 9        13                          On StartNG Pre-Internship
# 10       15                                                why
# 11       16                                        Please note
# 12       20                      HNG internship journey so far
# 13       21                                 What I done so far
# 14       23                          Learnt Learn and Learning
# 15       24                Learning Web development at StartNg
# 16       25  The Journey with StartNG: Creating my CV with ...
# 17       26                What i have done so far on start.ng
# 18       27                                      Task Number 7
# 19       29                       What has been learnt so far?
# 20       30                    WHAT I HAVE DONE SO FAR ON HTML
# 21       32                                             TASK 2
# 22       33                           CURRICULUM VITAE IN HTML
# 23       34                                HNG start.ng Task 2
# 24       35                                          kikkymakz
# 25       36                                   StartNg Task One
# 26       37                                 The Journey so far
# 27       39                          HTML: The journey so far.
# 28       40                    Public Journal :task 2. HTML CV
# 29       41                                   My CV using HTML
# 30       42                              My HTML work on Slack
# 31       46              My First Week in the StartNG Bootcamp
# 32       47                       As the Journey continues !!!
# 33       48                       As the Journey continues !!!
# 34       49                     A New Path: HNG Pre-Internship
# 35       50                     A new Path: HNG Pre-internship
# 36       52                              Learning with Startng
# 37       55                                     Startng task 2
# 38       56            What i have learnt so far from Start.ng
# 39       57                       Lucid post to start.ng Task1
# 40       59                             lucid post to start.ng
# 41       60                                 Myself and Startng
# 42       62  Towards Becoming a Software Engineer, A case S...
# 43       63                   HTML Course so far on startdotng
# 44       64                                             Task 2
# 45       65                                    StartNG Stage 1
# 46       67                       Lucid post to start.ng Task1
# 47       78          Task two of my Start.NG internship so far
# 48       79                                  CLASS HAS STARTED
# 49       80                    My Experience At StartNG So far
#
#                                               content
# 0   I learnt how to use the table tag as i have us...
# 1    I am on this journey with start.ng, and here ...
# 2   I have not been attending classes on the HNG c...
# 3   My journey on **StartNG** pre-internship progr...
# 4    A Summary on The “idongesit.html” CV, Its Str...
# 5   Using the Hyper Text Markup Language (HTML) ha...
# 6   ![](/storage/2040/images/img-kf6sy3kvg0.png)![...
# 7   My journey on **StartNG** pre-internship progr...
# 8   <p> </p>\n<p>I have learned a lot about HTML a...
# 9   **What I have learned so far**\n\nI have learn...
# 10                                       lucid why na
# 11  The screenshot of my HTML CV attached to my la...
# 12  So far on the HNG pre-internship we've been ab...
# 13  I have learnt about html tags, heading, the ve...
# 14  So far into the world of technologies I've bee...
# 15  With this opportunity brought to me by StartNg...
# 16  In my previous post, I talked about all the in...
# 17  <p>When I embarked on this internship, i would...
# 18  <p><strong>What I have learnt so far:</strong>...
# 19  It has been an interesting journey so far, hav...
# 20  ![](/storage/225/images/img-5y3zt92b66.png)Wha...
# 21  HI GUYS\n-------\n\nOn the previous post I tal...
# 22  Exploring the possibilities that exists in the...
# 23  The second task that was alloted to us (the pr...
# 24  1.  Achieveing this was a huge success on my p...
# 25  **What i have learnt so far:**\n\n> I have lea...
# 26  I just created my first html page guys!!!!!! I...
# 27  HTML (HyperText Markup Language) is a language...
# 28  firstly I cant find my previous entry. My firs...
# 29  This week's task opened my eyes to a possibili...
# 30  Its been an enterprising lesson on HTML, the l...
# 31  During my first week in the StartNG classes, I...
# 32  <p>Although, I have got some idea what the HNG...
# 33  <p>Although, I have got some idea what the HNG...
# 34  <p>I just started my journey to a new path. A ...
# 35  <p>I just started my journey to a new path. A ...
# 36  This is my first time and first post on Lucid,...
# 37  I have learnt a lot on the basics of HTML. Bel...
# 38  Start.ng have been a wonderful p![](/storage/1...
# 39  <p>I have learnt how to use break point and so...
# 40  <p>i have learnt some basic platform like slac...
# 41  As a young lady in this computer age, I really...
# 42  ![](/storage/1133/images/img-zplxyakz2a.png)\n...
# 43  On Start.ng I have learnt the HTML document st...
# 44  ![](/storage/1968/images/img-3igapldin9.png)In...
# 45  Hi guys, my name is Damian Tochukwu, i go by t...
# 46  I have learnt how to use break point and some ...
# 47  The HTML also known as Hyper Text Markup Langu...
# 48  <p>As your can read it on the top, yes, class ...
# 49  <h3>By the curiosity of trying everything I ca...

# %%
TF = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
TFIDF_MATRIX = TF.fit_transform(POSTS['title'])

COSINE_SIMILARITIES = linear_kernel(TFIDF_MATRIX, TFIDF_MATRIX)

RESULTS = {}

for idx, row in POSTS.iterrows():
    similar_indices = COSINE_SIMILARITIES[idx].argsort()[:-100:-1]
    similar_items = [(COSINE_SIMILARITIES[idx][i], POSTS['post_id'][i]) for i in similar_indices]

    # First post is the post itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, post_id)
    RESULTS[row['post_id']] = similar_items[1:]

print('done!')
# Out:
# done!

# %% [markdown]
# #### Step 2: Predict!

# %%
def post(p_id):
    """ Function to get an article title from the title field,
    given a post ID """
    return POSTS[POSTS['post_id'] == p_id]['title'].tolist()[0].split(' - ')[0]


def recommend(post_id, num):
    """ Function to reads the results out of the dictionary. """
    print("Recommending " + str(num) + " articles similar to " + post(post_id) + "...")
    print("--------------------------------------------------------------------------")
    recs = RESULTS[post_id][:num]
    for rec in recs:
        print("Recommended: " + post(rec[1]) + " (score:" + str(rec[0]) + ")")

# Just plug in any post id here (about 800 posts in the dataset), and the number of recommendations you want (1-99)
# You can get a list of valid post IDs by evaluating the variable 'POSTS'

# %%
recommend(post_id=33, num=5)
# Out:
# Recommending 5 articles similar to CURRICULUM VITAE IN HTML...
# --------------------------------------------------------------------------
# Recommended: curriculum vitae (score:0.6995945842991993)
# Recommended: curriculum vitae (score:0.6995945842991993)
# Recommended: curriculum vitae (score:0.6995945842991993)
# Recommended: My Curriculum Vitae (score:0.6995945842991993)
# Recommended: curriculum vitae (score:0.6995945842991993)
